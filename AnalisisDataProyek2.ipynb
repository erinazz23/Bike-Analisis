# %% [markdown]
# # Proyek Analisis Data: [Bike-Sharing-Dataset]
# - **Nama:** [Erin Handayani Azzahra]
# - **Email:** [erinhandayani23@gmail.com]
# - **ID Dicoding:** [erinhandayani23]

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Bagaimana sistem manajemen stok sepeda diatur? Bagaimana menyediakan sepeda yang memadai untuk permintaan pengguna?
# - Apakah ada program loyalitas atau promosi yang ditawarkan kepada pengguna yang sering menggunakan layanan ini?
# - Apakah ada tren jangka panjang dalam penggunaan sepeda yang dapat diidentifikasi dari dataset?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import zipfile
import requests
from io import BytesIO

import warnings
warnings.filterwarnings("ignore")
github_dataset_url = 'https://github.com/erinazz23/repository/raw/main/bike.zip'

# %%
day_df = pd.read_csv("https://raw.githubusercontent.com/erinazz23/Bike-Analisis/master/data/day.csv ")
day_df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
#membaca dataset hari
day = pd.read_csv("https://raw.githubusercontent.com/erinazz23/Bike-Analisis/master/data/day.csv")
print(day.shape)
day.head()
# Out:
# (731, 16)
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
#membaca dataset jam
hour = pd.read_csv("https://raw.githubusercontent.com/erinazz23/Bike-Analisis/master/data/hour.csv")
print(hour.shape)
hour.head()
# Out:
# (17379, 17)
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
#menghitung setiap jumlah baris pada dataframe
print("Jumlah baris di DataFrame day:", day.shape[0])
print("Jumlah baris di DataFrame hour:", hour.shape[0])
# Out:
# Jumlah baris di DataFrame day: 731
# Jumlah baris di DataFrame hour: 17379

# %%
#menggabungkan tabel
bike_sharing = day.merge(hour, on='dteday', how='inner', suffixes=('_daily', '_hourly'))
print(bike_sharing.shape)
# df_product.head()
bike_sharing.loc[bike_sharing["dteday"].isnull()]
bike_sharing.head()
# Out:
# (17379, 32)
#    instant_daily      dteday  season_daily  yr_daily  mnth_daily  \
# 0              1  2011-01-01             1         0           1
# 1              1  2011-01-01             1         0           1
# 2              1  2011-01-01             1         0           1
# 3              1  2011-01-01             1         0           1
# 4              1  2011-01-01             1         0           1
#
#    holiday_daily  weekday_daily  workingday_daily  weathersit_daily  \
# 0              0              6                 0                 2
# 1              0              6                 0                 2
# 2              0              6                 0                 2
# 3              0              6                 0                 2
# 4              0              6                 0                 2
#
#    temp_daily  ...  weekday_hourly  workingday_hourly  weathersit_hourly  \
# 0    0.344167  ...               6                  0                  1
# ...

# %% [markdown]
# ### Assessing Data

# %%
#memeriksa DataFrame
hour.info()
day.info()
bike_sharing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB
# ...

# %%
#menilai data hari
day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %%
#menilai data bike
print(bike_sharing.shape)
bike_sharing.isnull().sum()
# Out:
# (17379, 32)
# instant_daily        0
# dteday               0
# season_daily         0
# yr_daily             0
# mnth_daily           0
# holiday_daily        0
# weekday_daily        0
# workingday_daily     0
# weathersit_daily     0
# temp_daily           0
# atemp_daily          0
# hum_daily            0
# windspeed_daily      0
# casual_daily         0
# registered_daily     0
# cnt_daily            0
# instant_hourly       0
# season_hourly        0
# yr_hourly            0
# mnth_hourly          0
# hr                   0
# holiday_hourly       0
# weekday_hourly       0
# workingday_hourly    0
# weathersit_hourly    0
# temp_hourly          0
# atemp_hourly         0
# hum_hourly           0
# windspeed_hourly     0
# casual_hourly        0
# registered_hourly    0
# cnt_hourly           0
# dtype: int64

# %% [markdown]
# dari hasil diatas terlihat 0 untuk missing value berarti dalam data bike tidak ada missing value

# %%
#jumlah duplikasi
print("Jumlah duplikasi: ", bike_sharing.duplicated().sum())
bike_sharing.describe()
# Out:
# Jumlah duplikasi:  0
#        instant_daily  season_daily      yr_daily    mnth_daily  holiday_daily  \
# count   17379.000000  17379.000000  17379.000000  17379.000000   17379.000000
# mean      367.172622      2.501640      0.502561      6.537775       0.028770
# std       210.072051      1.106918      0.500008      3.438776       0.167165
# min         1.000000      1.000000      0.000000      1.000000       0.000000
# 25%       185.000000      2.000000      0.000000      4.000000       0.000000
# 50%       367.000000      3.000000      1.000000      7.000000       0.000000
# 75%       549.000000      3.000000      1.000000     10.000000       0.000000
# max       731.000000      4.000000      1.000000     12.000000       1.000000
#
#        weekday_daily  workingday_daily  weathersit_daily    temp_daily  \
# count   17379.000000      17379.000000      17379.000000  17379.000000
# mean        3.003683          0.682721          1.391680      0.496987
# ...

# %% [markdown]
# tidak terdapat duplikasi data dalam data bike

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# tidak terdapat missing value dan duplikasi maka data tidak perlu melalui tahap cleaning data

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
# mendefinisikan fungsi yang akan digunakan untuk EDA
def range(series):
    return series.max() - series.min()

# %%
bike_sharing.describe(include="all")
# Out:
#         instant_daily      dteday  season_daily      yr_daily    mnth_daily  \
# count    17379.000000       17379  17379.000000  17379.000000  17379.000000
# unique            NaN         731           NaN           NaN           NaN
# top               NaN  2011-01-01           NaN           NaN           NaN
# freq              NaN          24           NaN           NaN           NaN
# mean       367.172622         NaN      2.501640      0.502561      6.537775
# std        210.072051         NaN      1.106918      0.500008      3.438776
# min          1.000000         NaN      1.000000      0.000000      1.000000
# 25%        185.000000         NaN      2.000000      0.000000      4.000000
# 50%        367.000000         NaN      3.000000      1.000000      7.000000
# 75%        549.000000         NaN      3.000000      1.000000     10.000000
# max        731.000000         NaN      4.000000      1.000000     12.000000
#
# ...

# %% [markdown]
# ### Explore ...

# %%
bike_sharing.groupby(by="season_hourly").agg({
    "workingday_hourly": "count", #menjumlahkan penyewa pada hari kerja berdasarkan musim
    "windspeed_hourly": ["max", "min", "mean", lambda x: x.max() - x.min()]  # Membuat fungsi kustom untuk range
}).sort_values(by=("workingday_hourly", "count"), ascending=False)
# Out:
#               workingday_hourly windspeed_hourly
#                           count              max  min      mean <lambda_0>
# season_hourly
# 3                          4496           0.8507  0.0  0.171593     0.8507
# 2                          4409           0.7164  0.0  0.203410     0.7164
# 1                          4242           0.8060  0.0  0.215107     0.8060
# 4                          4232           0.6418  0.0  0.170819     0.6418

# %%
bike_sharing.groupby(by="season_daily").agg({
    "workingday_daily": "count", #menjumlahkan penyewa pada hari kerja berdasarkan musim
    "windspeed_daily": ["max", "min", "mean", lambda x: x.max() - x.min()]  # Membuat fungsi kustom untuk range
}).sort_values(by=("workingday_daily", "count"), ascending=False)
# Out:
#              workingday_daily windspeed_daily
#                         count             max       min      mean <lambda_0>
# season_daily
# 3                        4496        0.375617  0.064071  0.171593   0.311546
# 2                        4409        0.388067  0.065929  0.203410   0.322138
# 1                        4242        0.507463  0.045408  0.215107   0.462055
# 4                        4232        0.422275  0.022392  0.170819   0.399883

# %%
bike_sharing.groupby(by="season_daily").mnth_daily .nunique()
# Out:
# season_daily
# 1    4
# 2    4
# 3    4
# 4    4
# Name: mnth_daily, dtype: int64

# %%
bike_sharing.groupby(by="season_daily").instant_daily.nunique()
# Out:
# season_daily
# 1    181
# 2    184
# 3    188
# 4    178
# Name: instant_daily, dtype: int64

# %%
bike_sharing.groupby(by="season_daily").cnt_daily.nunique()
# Out:
# season_daily
# 1    179
# 2    182
# 3    188
# 4    176
# Name: cnt_daily, dtype: int64

# %%
bike_sharing.groupby(by="season_daily").cnt_hourly.nunique()
# Out:
# season_daily
# 1    482
# 2    721
# 3    760
# 4    690
# Name: cnt_hourly, dtype: int64

# %%
bike_sharing.groupby(by="weathersit_daily").cnt_hourly.nunique()
# Out:
# weathersit_daily
# 1    841
# 2    686
# 3    187
# Name: cnt_hourly, dtype: int64

# %%
#pengelompokkan kata berdasarkan kolom "weathersit_daily"
bike_sharing.groupby(by="weathersit_daily").cnt_daily.nunique()
# Out:
# weathersit_daily
# 1    451
# 2    243
# 3     21
# Name: cnt_daily, dtype: int64

# %%
#korelasi data perhari
numerical_columns = ["holiday_daily"
 ,"weekday_daily","workingday_daily","weathersit_daily","temp_daily","atemp_daily","season_daily", "windspeed_daily",  "cnt_daily"]
correlation = bike_sharing[numerical_columns].corr()
print(correlation)
# Out:
#                   holiday_daily  weekday_daily  workingday_daily  \
# holiday_daily          1.000000      -0.102088         -0.252471
# weekday_daily         -0.102088       1.000000          0.035955
# workingday_daily      -0.252471       0.035955          1.000000
# weathersit_daily      -0.033653       0.035082          0.057122
# temp_daily            -0.028856      -0.001894          0.058460
# atemp_daily           -0.032770      -0.009333          0.057839
# season_daily          -0.009585      -0.002335          0.013743
# windspeed_daily        0.006319       0.018226         -0.018746
# cnt_daily             -0.070344       0.064204          0.068216
#
#                   weathersit_daily  temp_daily  atemp_daily  season_daily  \
# holiday_daily            -0.033653   -0.028856    -0.032770     -0.009585
# weekday_daily             0.035082   -0.001894    -0.009333     -0.002335
# workingday_daily          0.057122    0.058460     0.057839      0.013743
# ...

# %% [markdown]
# dari penjelasan diatas jumlah penyewa sepeda memiliki hubungan yang negatif terhadap hari libur, cuaca, dan kecepatan angin

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Bagaimana sistem manajemen stok sepeda diatur? Bagaimana menyediakan sepeda yang memadai untuk permintaan pengguna?

# %%
seasonal_inventory = bike_sharing.groupby('season_daily')['cnt_daily'].sum()
season_names = ['Spring', 'Summer', 'Fall', 'Winter']
seasonal_renters = bike_sharing.groupby('season_daily')['cnt_daily'].mean()
plt.bar(season_names, seasonal_inventory, color='skyblue', label='Stok Sepeda')
plt.plot(season_names, seasonal_renters, color='orange', marker='o', linestyle='-', linewidth=2, label='Penyewa Sepeda')
plt.xlabel('Musim')
plt.ylabel('Jumlah')
plt.title('Hubungan Penyewa Sepeda dengan Banyaknya Sepeda')
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Menambahkan garis-garis grid pada sumbu y
plt.show()

# %% [markdown]
# pada diagram batang diatas terlihat bahwa pada musim fall,permintaan naik

# %% [markdown]
# ### Pertanyaan 2:Apakah ada tren jangka panjang dalam penggunaan sepeda yang dapat diidentifikasi dari dataset?

# %%
# Membaca data sepeda
bike_data = pd.read_csv("https://raw.githubusercontent.com/erinazz23/Bike-Analisis/master/data/day.csv")

# Mengonversi kolom tanggal menjadi tipe data datetime
bike_data['tanggal'] = pd.to_datetime(bike_data['dteday'])

# Mengatur kolom tanggal sebagai indeks
bike_data.set_index('tanggal', inplace=True)

# Resampling data menjadi data bulanan dan menghitung total penggunaan sepeda per bulan
monthly_bike_usage = bike_data['cnt'].resample('M').sum()

# Membaca data tambahan
additional_data = pd.read_csv("https://raw.githubusercontent.com/erinazz23/Bike-Analisis/master/data/day.csv")

# Mengonversi kolom tanggal menjadi tipe data datetime
additional_data['tanggal'] = pd.to_datetime(additional_data['dteday'])

# Mengatur kolom tanggal sebagai indeks
additional_data.set_index('tanggal', inplace=True)

# Resampling data tambahan menjadi data bulanan dan menghitung total penggunaan sepeda per bulan
monthly_additional_usage = additional_data['cnt'].resample('M').sum()

# Menggabungkan kedua dataset
merged_data = pd.concat([monthly_bike_usage, monthly_additional_usage], axis=1)
merged_data.columns = ['Penggunaan Awal', 'Penggunaan Tambahan']

# Membuat plot tren jangka panjang
plt.figure(figsize=(10, 6))
plt.plot(merged_data.index, merged_data['Penggunaan Awal'], color='skyblue', marker='o', label='Penggunaan Awal')
plt.plot(merged_data.index, merged_data['Penggunaan Tambahan'], color='orange', marker='o', label='Penggunaan Tambahan')
plt.title('Tren Jangka Panjang Penggunaan Sepeda')
plt.xlabel('Tanggal')
plt.ylabel('Jumlah Penggunaan Sepeda')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# pada gambar diatas terlihat bahwa terjadi tren kenaikan dari tahun 2011 namun turun di 2012 kemudian naik lagi sampai tanggal 10 tahun 2012 kemudian turun secara signifikan pada tahun 2013, ini dapat dikaji proses terjadinya penurunan minat dan ditingkatkan lagi agar tren penggunaan sepeda menjadi meningkat lagi

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ### 1.Bagaimana sistem manajemen stok sepeda diatur? Bagaimana menyediakan sepeda yang memadai untuk permintaan pengguna?
# pada diagram batang diatas terlihat bahwa pada musim fall,permintaan naik yang berarti harus menyediakan stok sepeda lebih banyak dari musim yang lain.hal ini dilakukan agar meminimalisir pengguna yang tidak kebagian sepeda, sehingga penyedia layanan harus menambah stok pada musim fall

# %% [markdown]
# ### 2.Apakah ada tren jangka panjang dalam penggunaan sepeda yang dapat diidentifikasi dari dataset?
#
# tren kenaikan terjadi dari tahun 2011 namun turun di 2012 kemudian naik lagi sampai tanggal 10 tahun 2012 kemudian turun secara signifikan pada tahun 2013, ini dapat dikaji proses terjadinya penurunan minat dan ditingkatkan lagi agar tren penggunaan sepeda menjadi meningkat lagi. penyedia layanan dapat memantau tren jangka panjang dalam penggunaan sepeda ini sehingga bisa menjadi bahan evaluasi.
